// %%
System.out.println("Hello Lab4");
// Out:
// Hello Lab4

// %%
interface Meal {
    void prepare();
}

class Burger implements Meal {
    public void prepare() {
        System.out.println("Preparing Burger Meal");
    }
}

class Pizza implements Meal {
    public void prepare() {
        System.out.println("Preparing Pizza Meal");
    }
}

class Salad implements Meal {
    public void prepare() {
        System.out.println("Preparing Salad Meal");
    }
}

class MealFactory {
    public static Meal createMeal(String type) {
        if (type.equalsIgnoreCase("burger")) {
            return new Burger();
        } else if (type.equalsIgnoreCase("pizza")) {
            return new Pizza();
        } else if (type.equalsIgnoreCase("salad")) {
            return new Salad();
        }

        return null;
    }
}

Meal meal1 = MealFactory.createMeal("burger");
meal1.prepare();

Meal meal2 = MealFactory.createMeal("pizza");
meal2.prepare();

Meal meal3 = MealFactory.createMeal("salad");
meal3.prepare();
// Out:
// Preparing Burger Meal
// Preparing Pizza Meal
// Preparing Salad Meal
